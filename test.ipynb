# %% [markdown]
# # Test & Playground

# %% [markdown]
# ## Imports

# %%
# IMPORTS
import pandas as pd

# %%
df = pd.read_csv("train.csv", sep="$")
df
# Out:
# /home/jannick/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (3,5,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0      id Gender  Age Driving_License Region_Code  \
# 0                1    Male     44   No            28.0          No
# 1                2    Male     76   No             3.0          No
# 2                3    Male     47   No            28.0          No
# 3                4    Male     21  Yes            11.0         Yes
# 4                5  Female     29  Yes            41.0         Yes
# ...            ...     ...    ...  ...             ...         ...
# 380994      380995    Male   46..   No              28          No
# 380995      380996    Male   46..   No              28          No
# 380996      380997  Female   28..  Yes              50         Yes
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 380999 entries, 0 to 380998
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            380999 non-null  int64
#  1   id                    379948 non-null  object
#  2   Gender                370107 non-null  object
#  3   Age                   380948 non-null  object
#  4   Driving_License       380999 non-null  object
#  5   Region_Code           380948 non-null  object
#  6   Previously_Insured    380948 non-null  object
#  7   Vehicle_Age           380948 non-null  object
#  8   Vehicle_Damage        380999 non-null  float64
#  9   Annual_Premium        380999 non-null  object
#  10  Policy_Sales_Channel  380948 non-null  object
#  11  Vintage               380999 non-null  object
#  12  Response              0 non-null       float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 40.7+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 380999 entries, 0 to 380998
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            380999 non-null  int64
#  1   id                    379948 non-null  object
#  2   Gender                370107 non-null  object
#  3   Age                   380948 non-null  object
#  4   Driving_License       380999 non-null  object
#  5   Region_Code           380948 non-null  object
#  6   Previously_Insured    380948 non-null  object
#  7   Vehicle_Age           380948 non-null  object
#  8   Vehicle_Damage        380999 non-null  float64
#  9   Annual_Premium        380999 non-null  object
#  10  Policy_Sales_Channel  380948 non-null  object
#  11  Vintage               380999 non-null  object
#  12  Response              0 non-null       float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 40.7+ MB
